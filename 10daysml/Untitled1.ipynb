# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")
df
# Out:
#       Unnamed: 0       Brand    Model  Model_year Transmission  \
# 0              0   Chevrolet     aveo        2009       Manual
# 1              1   Chevrolet  captiva        2015    Automatic
# 2              2   Chevrolet     aveo        2009       Manual
# 3              3   Chevrolet  captiva        2010    Automatic
# 4              4   Chevrolet    spark        2012       Manual
# ...          ...         ...      ...         ...          ...
# 1894        2209  Volkswagen     polo        2013       Manual
# 1895        2210  Volkswagen   beetle        2010       Manual
# 1896        2211  Volkswagen   passat        2010       Manual
# 1897        2213  Volkswagen   tiguan        2010       Manual
# 1898        2215  Volkswagen    vento        2012       Manual
#
#       Engine_size(cc)  Drivetrain Fuel_type  Lot_no  Kilometer    Price
# 0                1150           2    Petrol       6        200   975000
# ...

# %%
sns.scatterplot(df['Model_year'],df['Price'],hue=df['Lot_no'],size=df['Engine_size(cc)'],style=df['Drivetrain'])
# Out:
# C:\Users\MR.D\anaconda3\envs\10daysml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Model_year', ylabel='Price'>

# %%
sns.barplot(df['Transmission'],df['Price'],hue=df['Drivetrain'])
# Out:
# C:\Users\MR.D\anaconda3\envs\10daysml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Transmission', ylabel='Price'>

# %%
sns.barplot(df['Engine_size(cc)'],df['Price'])
# Out:
# C:\Users\MR.D\anaconda3\envs\10daysml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Engine_size(cc)', ylabel='Price'>

# %%
sns.scatterplot(df['Engine_size(cc)'],df['Price'],size=df['Kilometer'])
# Out:
# C:\Users\MR.D\anaconda3\envs\10daysml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Engine_size(cc)', ylabel='Price'>

# %%
df.loc[(df['Brand']=="Chevrolet")&(df['Lot_no']>10)]
# Out:
#     Unnamed: 0      Brand    Model  Model_year Transmission  Engine_size(cc)  \
# 13          13  Chevrolet    spark        2012       Manual             1000
# 35          35  Chevrolet      uva        2007       Manual             1400
# 43          43  Chevrolet     aveo        2013       Manual             1600
# 59          59  Chevrolet     aveo        2012       Manual             1600
# 64          64  Chevrolet  captiva        2011       Manual             2500
#
#     Drivetrain Fuel_type  Lot_no  Kilometer    Price
# 13           2    Petrol      15      40000  1100000
# 35           2    Petrol      12      40000  1050000
# 43           4    Petrol      12       3800  2000000
# 59           2    Petrol      12      19000  2200000
# 64           2    Diesel      11      50000  3000000

# %%
df
# Out:
#       Unnamed: 0       Brand    Model  Model_year Transmission  \
# 0              0   Chevrolet     aveo        2009       Manual
# 1              1   Chevrolet  captiva        2015    Automatic
# 2              2   Chevrolet     aveo        2009       Manual
# 3              3   Chevrolet  captiva        2010    Automatic
# 4              4   Chevrolet    spark        2012       Manual
# ...          ...         ...      ...         ...          ...
# 1894        2209  Volkswagen     polo        2013       Manual
# 1895        2210  Volkswagen   beetle        2010       Manual
# 1896        2211  Volkswagen   passat        2010       Manual
# 1897        2213  Volkswagen   tiguan        2010       Manual
# 1898        2215  Volkswagen    vento        2012       Manual
#
#       Engine_size(cc)  Drivetrain Fuel_type  Lot_no  Kilometer    Price
# 0                1150           2    Petrol       6        200   975000
# ...

# %%
df.iloc[0,4]
# Out:
# ' Manual'

# %%
df
# Out:
#       Unnamed: 0       Brand    Model  Model_year Transmission  \
# 0              0   Chevrolet     aveo        2009       Manual
# 1              1   Chevrolet  captiva        2015    Automatic
# 2              2   Chevrolet     aveo        2009       Manual
# 3              3   Chevrolet  captiva        2010    Automatic
# 4              4   Chevrolet    spark        2012       Manual
# ...          ...         ...      ...         ...          ...
# 1894        2209  Volkswagen     polo        2013       Manual
# 1895        2210  Volkswagen   beetle        2010       Manual
# 1896        2211  Volkswagen   passat        2010       Manual
# 1897        2213  Volkswagen   tiguan        2010       Manual
# 1898        2215  Volkswagen    vento        2012       Manual
#
#       Engine_size(cc)  Drivetrain Fuel_type  Lot_no  Kilometer    Price
# 0                1150           2    Petrol       6        200   975000
# ...

# %%
df.drop(['Brand','Model'],axis=1)
# Out:
#       Unnamed: 0  Model_year Transmission  Engine_size(cc)  Drivetrain  \
# 0              0        2009       Manual             1150           2
# 1              1        2015    Automatic             2000           4
# 2              2        2009       Manual             1150           2
# 3              3        2010    Automatic             2000           4
# 4              4        2012       Manual             1000           2
# ...          ...         ...          ...              ...         ...
# 1894        2209        2013       Manual             1600           2
# 1895        2210        2010       Manual             1595           2
# 1896        2211        2010       Manual             1800           2
# 1897        2213        2010       Manual             2000           2
# 1898        2215        2012       Manual             1600           2
#
#      Fuel_type  Lot_no  Kilometer    Price
# 0       Petrol       6        200   975000
# ...
