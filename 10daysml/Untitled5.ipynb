# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')
df
# Out:
#       Unnamed: 0       Brand    Model  Model_year Transmission  \
# 0              0   Chevrolet     aveo        2009       Manual
# 1              1   Chevrolet  captiva        2015    Automatic
# 2              2   Chevrolet     aveo        2009       Manual
# 3              3   Chevrolet  captiva        2010    Automatic
# 4              4   Chevrolet    spark        2012       Manual
# ...          ...         ...      ...         ...          ...
# 1894        2209  Volkswagen     polo        2013       Manual
# 1895        2210  Volkswagen   beetle        2010       Manual
# 1896        2211  Volkswagen   passat        2010       Manual
# 1897        2213  Volkswagen   tiguan        2010       Manual
# 1898        2215  Volkswagen    vento        2012       Manual
#
#       Engine_size(cc)  Drivetrain Fuel_type  Lot_no  Kilometer    Price
# 0                1150           2    Petrol       6        200   975000
# 1                2000           4    Diesel       8        100  3000000
# 2                1150           2    Petrol       6      42000   975000
# 3                2000           4    Diesel       8      51000  3000000
# 4                1000           2    Petrol       9      38000  1000000
# ...               ...         ...       ...     ...        ...      ...
# 1894             1600           2    Petrol      11       6300  2700000
# 1895             1595           2    Petrol       8      19000  3950000
# 1896             1800           2    Petrol       8      11000  5800000
# 1897             2000           2    Petrol       8      25000  4900000
# 1898             1600           2    Diesel      11      14000  3555555
#
# [1899 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
# Out:
#       Unnamed: 0       Brand    Model  Model_year Transmission  \
# 0              0   Chevrolet     aveo        2009       Manual
# 1              1   Chevrolet  captiva        2015    Automatic
# 2              2   Chevrolet     aveo        2009       Manual
# 3              3   Chevrolet  captiva        2010    Automatic
# 4              4   Chevrolet    spark        2012       Manual
# ...          ...         ...      ...         ...          ...
# 1894        2209  Volkswagen     polo        2013       Manual
# 1895        2210  Volkswagen   beetle        2010       Manual
# 1896        2211  Volkswagen   passat        2010       Manual
# 1897        2213  Volkswagen   tiguan        2010       Manual
# 1898        2215  Volkswagen    vento        2012       Manual
#
#       Engine_size(cc)  Drivetrain Fuel_type  Lot_no  Kilometer    Price
# 0                1150           2    Petrol       6        200   975000
# 1                2000           4    Diesel       8        100  3000000
# 2                1150           2    Petrol       6      42000   975000
# 3                2000           4    Diesel       8      51000  3000000
# 4                1000           2    Petrol       9      38000  1000000
# ...               ...         ...       ...     ...        ...      ...
# 1894             1600           2    Petrol      11       6300  2700000
# 1895             1595           2    Petrol       8      19000  3950000
# 1896             1800           2    Petrol       8      11000  5800000
# 1897             2000           2    Petrol       8      25000  4900000
# 1898             1600           2    Diesel      11      14000  3555555
#
# [1899 rows x 11 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop('Price',axis=1),df['Price'],test_size=0.3,random_state=0)
X_train.shape,y_train.shape
X_train
# Out:
#       Unnamed: 0          Brand   Model  Model_year Transmission  \
# 940          940        Hyundai  accent        2009       Manual
# 1108        1108       Mahindra     Kuv        2016       Manual
# 432          432        Hyundai     i10        2010       Manual
# 576          576        Hyundai  santro        2009       Manual
# 658          658        Hyundai    asta        2010       Manual
# ...          ...            ...     ...         ...          ...
# 835          835        Hyundai     i10        2010       Manual
# 1216        1221  Maruti Suzuki    Omni        2009       Manual
# 1653        1867           Tata  safari        2014       Manual
# 559          559        Hyundai     i10        2010       Manual
# 684          684        Hyundai  santro        2000       Manual
#
#       Engine_size(cc)  Drivetrain Fuel_type  Lot_no  Kilometer
# 940              1400           2    Petrol       7      43623
# 1108             1200           2    Petrol      16      28000
# 432              1200           2    Petrol       9      31000
# 576              1100           2    Petrol       7      29000
# 658              1200           2    Petrol       8      36000
# ...               ...         ...       ...     ...        ...
# 835              1200           2    Petrol       9      26000
# 1216              800           2    Petrol       7      52000
# 1653             2200           4    Diesel      12      20000
# 559              1200           2    Petrol       7      30000
# 684              1000           2    Petrol       3      60000
#
# [1329 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-3306a1faae3c> in <module>
# ----> 1 scaler.fit(X_train)
#
# ~\anaconda3\envs\10daysml\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\envs\10daysml\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# ~\anaconda3\envs\10daysml\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\envs\10daysml\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\10daysml\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\envs\10daysml\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\envs\10daysml\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~\anaconda3\envs\10daysml\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'Hyundai'
